# %% [markdown]
# # Albedo Regression Example
#
# <img width="50%" src="../img/Lunar_Albedo_Header.png"> </img>

# %% [markdown]
# # Imports

# %%
import ROOT
from ROOT import TMVA,TFile, TTree, TCut, TString, TCanvas,  TASImage
import matplotlib.pyplot as plt
import numpy as np
import pandas as p
# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.12/06

# %%
# Chemical Composition Maps

<img width="50%" src="../img/Lunar_Composition_Maps.png"> </img>

# %% [markdown]
# # Plotting raw data

# %%
img=np.genfromtxt('data/Albedo_Map.csv',delimiter=',')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ## Declare Factory
# Initiate the TMVA library, get the data sample from github, and create a factory to do the regression.

# %%
TMVA.Tools.Instance();

inputFile = TFile.Open("data/dataset.root");
outputFile = TFile.Open("TMVAOutputBDT.root", "RECREATE");

factory = TMVA.Factory("TMVARegression", outputFile,
                      "!V:!Silent:Color:DrawProgressBar:AnalysisType=Regression" );

# %% [markdown]
# ## Declare DataLoader
# Define the features and the target for the regression.

# %%
loader = TMVA.DataLoader("dataset"); 

#Add the feature variables, names reference branches in inputFile ttree
loader.AddVariable("Fast_Map_extra", "", "units", 'F' );
loader.AddVariable("LPFe_Map", "", "units", 'F' );
loader.AddVariable("LPK_Map_extra", "", "units", 'F' );
loader.AddVariable("LPTh_Map", "", "units", 'F' );
loader.AddVariable("LPTi_Map", "", "units", 'F' );
loader.AddVariable("Therm_Map", "", "units", 'F' );

loader.AddTarget( "Albedo_Map" ); # define the target for the regression

# %% [markdown]
# ## Setup Dataset
# Link dataloader to dataset.

# %%
tree=TTree()
inputFile.GetObject("TreeR", tree);

mycuts = TCut(""); # e.g. TCut mycuts = "abs(var1)<0.5";

loader.AddRegressionTree(tree, 1.0);   # link the TTree to the loader, weight for each event  = 1
loader.PrepareTrainingAndTestTree(mycuts,"nTrain_Regression=129600:nTest_Regression=129960:SplitMode=Random:NormMode=NumEvents:!V" );
# Out:
# DataSetInfo              : [dataset] : Added class "Regression"
#                          : Add Tree TreeR of type Regression with 259560 events
#                          : Dataset[dataset] : Class index : 0  name : Regression

# %% [markdown]
# # Book The Regression Method

# %% [markdown]
# Book the method for regression. Here we choose the Boosted Decision Tree model. You have to use gradient boosted trees for regression, hence the BDTG and BoostType=Grad.
#
# Define the hyperparameters: ntrees, boosttype, shrinkage, and the depth. Also define the loss function you want to use: 'AbsoluteDeviation', 'Huber', or 'LeastSquares'. nCuts determines how finely to look at each feature. Larger values take more time, but you may get more accurate results.

# %%
# Boosted Decision Trees 
factory.BookMethod(loader,TMVA.Types.kBDT, "BDTG","!H:!V:NTrees=200::BoostType=Grad:Shrinkage=0.3:nCuts=20:MaxDepth=4:RegressionLossFunctionBDTG=AbsoluteDeviation");
# Out:
# Factory                  : Booking method: BDTG
#                          :
#                          : the option *InverseBoostNegWeights* does not exist for BoostType=Grad --> change
#                          : to new default for GradBoost *Pray*
# DataSetFactory           : [dataset] : Number of events in input trees
#                          :
#                          : Number of training and testing events
#                          : ---------------------------------------------------------------------------
#                          : Regression -- training events            : 129600
#                          : Regression -- testing events             : 129960
#                          : Regression -- training and testing events: 259560
#                          :
# DataSetInfo              : Correlation matrix (Regression):
#                          : ---------------------------------------------------------------------------------
#                          :                 Fast_Map_extra LPFe_Map LPK_Map_extra LPTh_Map LPTi_Map Therm_Map
#                          : Fast_Map_extra:         +1.000   +0.901        +0.609   +0.640   +0.797    -0.853
#                          :       LPFe_Map:         +0.901   +1.000        +0.691   +0.726   +0.804    -0.892
#                          :  LPK_Map_extra:         +0.609   +0.691        +1.000   +0.937   +0.555    -0.829
#                          :       LPTh_Map:         +0.640   +0.726        +0.937   +1.000   +0.593    -0.851
#                          :       LPTi_Map:         +0.797   +0.804        +0.555   +0.593   +1.000    -0.737
#                          :      Therm_Map:         -0.853   -0.892        -0.829   -0.851   -0.737    +1.000
#                          : ---------------------------------------------------------------------------------
# DataSetFactory           : [dataset] :
#                          :

# %% [markdown]
# # Train Method

# %%
factory.TrainAllMethods();
# Out:
# Factory                  : Train all methods
# Factory                  : [dataset] : Create Transformation "I" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'Fast_Map_extra' <---> Output : variable 'Fast_Map_extra'
#                          : Input : variable 'LPFe_Map' <---> Output : variable 'LPFe_Map'
#                          : Input : variable 'LPK_Map_extra' <---> Output : variable 'LPK_Map_extra'
#                          : Input : variable 'LPTh_Map' <---> Output : variable 'LPTh_Map'
#                          : Input : variable 'LPTi_Map' <---> Output : variable 'LPTi_Map'
#                          : Input : variable 'Therm_Map' <---> Output : variable 'Therm_Map'
# TFHandler_Factory        :       Variable              Mean              RMS      [        Min              Max ]
#                          : -----------------------------------------------------------------------------------------
#                          : Fast_Map_extra:          407.81          18.509   [          376.24          499.79 ]
#                          :       LPFe_Map:          5.2571          3.3843   [          0.0000          23.902 ]
#                          :  LPK_Map_extra:          724.61          675.40   [          0.0000          4356.4 ]
#                          :       LPTh_Map:          1.5877          1.7453   [       0.0036630          11.644 ]
#                          :       LPTi_Map:         0.49989         0.76665   [          0.0000          7.1879 ]
#                          :      Therm_Map:          573.07          115.27   [          227.91          761.53 ]
#                          :     Albedo_Map:         0.29196        0.052916   [         0.10035         0.50656 ]
#                          : -----------------------------------------------------------------------------------------
#                          : Ranking input variables (method unspecific)...
# IdTransformation         : Ranking result (top variable is best ranked)
#                          : ------------------------------------------------------
#                          : Rank : Variable       : |Correlation with target|
#                          : ------------------------------------------------------
#                          :    1 : Fast_Map_extra : 8.329e-01
#                          :    2 : LPFe_Map       : 8.106e-01
#                          :    3 : Therm_Map      : 8.096e-01
#                          :    4 : LPTi_Map       : 6.827e-01
#                          :    5 : LPTh_Map       : 5.740e-01
#                          :    6 : LPK_Map_extra  : 5.475e-01
#                          : ------------------------------------------------------
# IdTransformation         : Ranking result (top variable is best ranked)
#                          : -----------------------------------------------
#                          : Rank : Variable       : Mutual information
#                          : -----------------------------------------------
#                          :    1 : Fast_Map_extra : -1.000e+00
#                          :    2 : LPFe_Map       : -1.000e+00
#                          :    3 : LPK_Map_extra  : -1.000e+00
#                          :    4 : LPTh_Map       : -1.000e+00
#                          :    5 : LPTi_Map       : -1.000e+00
#                          :    6 : Therm_Map      : -1.000e+00
#                          : -----------------------------------------------
# IdTransformation         : Ranking result (top variable is best ranked)
#                          : ----------------------------------------------
#                          : Rank : Variable       : Correlation Ratio
#                          : ----------------------------------------------
#                          :    1 : Fast_Map_extra : -1.000e+00
#                          :    2 : LPFe_Map       : -1.000e+00
#                          :    3 : LPK_Map_extra  : -1.000e+00
#                          :    4 : LPTh_Map       : -1.000e+00
#                          :    5 : LPTi_Map       : -1.000e+00
#                          :    6 : Therm_Map      : -1.000e+00
#                          : ----------------------------------------------
# IdTransformation         : Ranking result (top variable is best ranked)
#                          : --------------------------------------------------
#                          : Rank : Variable       : Correlation Ratio (T)
#                          : --------------------------------------------------
#                          :    1 : Fast_Map_extra : -1.000e+00
#                          :    2 : LPFe_Map       : -1.000e+00
#                          :    3 : LPK_Map_extra  : -1.000e+00
#                          :    4 : LPTh_Map       : -1.000e+00
#                          :    5 : LPTi_Map       : -1.000e+00
#                          :    6 : Therm_Map      : -1.000e+00
#                          : --------------------------------------------------
# Factory                  : Train method: BDTG for Regression
#                          :
#                          : Regression Loss Function: AbsoluteDeviation
#                          : Training 200 Decision Trees ... patience please
#                          : Elapsed time for training with 129600 events: 43.8 sec
#                          : Dataset[dataset] : Create results for training
#                          : Dataset[dataset] : Evaluation of BDTG on training sample
#                          : Dataset[dataset] : Elapsed time for evaluation of 129600 events: 2.78 sec
#                          : Create variable histograms
#                          : Create regression target histograms
#                          : Create regression average deviation
#                          : Results created
#                          : Creating xml weight file: dataset/weights/TMVARegression_BDTG.weights.xml
# Factory                  : Training finished
#                          :
# Factory                  : === Destroy and recreate all methods via weight files for testing ===
#                          :
# 0%, time left: unknown
# 7%, time left: 48 sec
# 13%, time left: 42 sec
# 19%, time left: 38 sec
# 25%, time left: 34 sec
# 32%, time left: 31 sec
# 38%, time left: 28 sec
# 44%, time left: 24 sec
# 50%, time left: 22 sec
# 57%, time left: 19 sec
# 63%, time left: 16 sec
# 69%, time left: 13 sec
# 75%, time left: 10 sec
# 82%, time left: 8 sec
# 88%, time left: 5 sec
# 94%, time left: 2 sec
# 0%, time left: unknown
# 6%, time left: 2 sec
# 12%, time left: 2 sec
# 18%, time left: 2 sec
# 25%, time left: 2 sec
# 31%, time left: 1 sec
# 37%, time left: 1 sec
# 43%, time left: 1 sec
# 50%, time left: 1 sec
# 56%, time left: 1 sec
# 62%, time left: 1 sec
# 68%, time left: 0 sec
# 75%, time left: 0 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec

# %% [markdown]
# # Test and Evaluate the Model

# %%
factory.TestAllMethods();
factory.EvaluateAllMethods();
# Out:
# Factory                  : Test all methods
# Factory                  : Test method: BDTG for Regression performance
#                          :
#                          : Dataset[dataset] : Create results for testing
#                          : Dataset[dataset] : Evaluation of BDTG on testing sample
#                          : Dataset[dataset] : Elapsed time for evaluation of 129960 events: 2.82 sec
#                          : Create variable histograms
#                          : Create regression target histograms
#                          : Create regression average deviation
#                          : Results created
# Factory                  : Evaluate all methods
#                          : Evaluate regression method: BDTG
# TFHandler_BDTG           :       Variable              Mean              RMS      [        Min              Max ]
#                          : -----------------------------------------------------------------------------------------
#                          : Fast_Map_extra:          407.99          18.687   [          376.24          499.79 ]
#                          :       LPFe_Map:          5.2848          3.4183   [          0.0000          23.902 ]
#                          :  LPK_Map_extra:          726.15          679.30   [          0.0000          4356.4 ]
#                          :       LPTh_Map:          1.5963          1.7547   [       0.0036630          11.644 ]
#                          :       LPTi_Map:         0.50554         0.77630   [          0.0000          7.1879 ]
#                          :      Therm_Map:          572.28          115.96   [          227.91          761.53 ]
#                          :     Albedo_Map:         0.29155        0.053257   [        0.096897         0.49938 ]
#                          : -----------------------------------------------------------------------------------------
#                          :
#                          : Evaluation results ranked by smallest RMS on test sample:
#                          : ("Bias" quotes the mean deviation of the regression from true target.
#                          :  "MutInf" is the "Mutual Information" between regression and target.
#                          :  Indicated by "_T" are the corresponding "truncated" quantities ob-
#                          :  tained when removing events deviating more than 2sigma from average.)
#                          : --------------------------------------------------------------------------------------------------
#                          : --------------------------------------------------------------------------------------------------
#                          : dataset              BDTG           :-0.000746-0.000262   0.0229   0.0185  |  0.727  0.836
#                          : --------------------------------------------------------------------------------------------------
#                          :
#                          : Evaluation results ranked by smallest RMS on training sample:
#                          : (overtraining check)
#                          : --------------------------------------------------------------------------------------------------
#                          : DataSet Name:         MVA Method:        <Bias>   <Bias_T>    RMS    RMS_T  |  MutInf MutInf_T
#                          : --------------------------------------------------------------------------------------------------
#                          : dataset              BDTG           :-0.000766-0.000286   0.0227   0.0182  |  0.733  0.845
#                          : --------------------------------------------------------------------------------------------------
#                          :
# Dataset:dataset          : Created tree 'TestTree' with 129960 events
#                          :
# Dataset:dataset          : Created tree 'TrainTree' with 129600 events
#                          :
# Factory                  : Thank you for using TMVA!
#                          : For citation information, please visit: http://tmva.sf.net/citeTMVA.html
# 0%, time left: unknown
# 6%, time left: 3 sec
# 12%, time left: 3 sec
# 18%, time left: 2 sec
# 25%, time left: 2 sec
# 31%, time left: 2 sec
# 37%, time left: 1 sec
# 43%, time left: 1 sec
# 50%, time left: 1 sec
# 56%, time left: 1 sec
# 62%, time left: 1 sec
# 68%, time left: 0 sec
# 75%, time left: 0 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec

# %% [markdown]
# ## Gather and Plot the Results
# Let's plot the residuals for the BDTG predictions. First, close the output file so that it saves to disk and we can open it without issue. Then get the results on the test set. Finally, plot the residuals.

# %%
# %jsroot on
outputFile.Close();
resultsFile = TFile.Open("TMVAOutputBDT.root");
resultsTree = resultsFile.Get("dataset/TestTree"); 
c=TCanvas() ;
resultsTree.Draw("BDTG"); # BDTG is the predicted value, target is the true value
c.Draw()
# Out:
# <div id="root_plot_1"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0.0793749973457305,"fY1":-1299.9000968501,"fX2":0.43562500265427,"fY2":11699.1000968501,"fXtoAbsPixelk":-155.073626714144,"fXtoPixelk":-155.073626714144,"fXtoPixel":1953.68418141415,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.0363104848808871,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":0.0793749973457305,"fPixeltoXk":0.0793749973457305,"fPixeltoX":5.11853455903073e-4,"fAbsPixeltoYk":11699.1000968501,"fPixeltoYk":-1299.9000968501,"fPixeltoY":-27.5402546476699,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0.115,"fUymin":0,"fUxmax":0.4,"fUymax":10399.2,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0.115,"fY1":0,"fX2":0.4,"fY2":10399.2,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331657,"fName":"htemp","fTitle":"BDTG","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"BDTG","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0.115,"fXmax":0.4,"fXbins":[],"fFirst":1,"fLast":100,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":129960,"fTsumw":129960,"fTsumw2":129960,"fTsumwx":37792.4114708751,"fTsumwx2":11285.0800903621,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0.357250007219613,"fY1":8774.32513074763,"fX2":0.428500009343028,"fY2":10854.1651152516,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"br ...
#        Core.draw("root_plot_1", obj, "");
#      }
#  );
# </script>

# %% [markdown]
# # Plots

# %%
result = np.genfromtxt ('data/result.txt', delimiter=",")

# %%
result = result.reshape(-1, 361)
np.savetxt('data/result.csv', result , delimiter=',') 
imgplot = plt.imshow(result) #Needs to be in row,col order
imgplot.set_cmap('nipy_spectral')
plt.clim(0.10,0.5)
plt.colorbar()
plt.show()

# %%
datatrain=p.read_csv("data/Albedo_Map.csv.train",dtype=float)
imgplot = plt.imshow(datatrain) #Needs to be in row,col order
imgplot.set_cmap('nipy_spectral')
plt.clim(0.10,0.5)
plt.colorbar()
plt.show()

# %%
datatest=p.read_csv("data/Albedo_Map.csv.test",dtype=float)
imgplot = plt.imshow(datatest) #Needs to be in row,col order
imgplot.set_cmap('nipy_spectral')
plt.clim(0.10,0.5)
plt.colorbar()
plt.show()

# %%
alldata=p.read_csv("data/Albedo_Map.csv",dtype=float)
imgplot = plt.imshow(alldata) #Needs to be in row,col order
imgplot.set_cmap('nipy_spectral')
plt.clim(0.10,0.5)
plt.colorbar()
plt.show()

# %%
alldatatrainresult=p.read_csv("data/AlbedoTrainResult.csv",dtype=float)
imgplot = plt.imshow(alldatatrainresult) #Needs to be in row,col order
imgplot.set_cmap('nipy_spectral')
plt.clim(0.10,0.5)
plt.colorbar()
plt.show()
